# %%
# Extract Data World Tattoo

# %%
import pandas as pd

# %%
#Import CSV and Creating Data frame
tattoo_df=pd.read_csv("Resources/NBA-Tattoos.csv", encoding="ISO-8859-1")
tattoo_df.head()
# Out:
#     Player Name Tattoos yes/no
# 0    A.J. Price             no
# 1    Aaron Gray             no
# 2    Al Horford             no
# 3  Al Jefferson             no
# 4   Al Thornton             no

# %%
# Checking for unique name 
uniquevalue=tattoo_df['Player Name'].unique()
len(uniquevalue)
# Out:
# 636

# %%
# Checking for unique name alternate approach
unvalue = tattoo_df['Player Name'].value_counts()
unvalue
# Out:
# Willie Warren             1
# Omri Casspi               1
# Kosta Koufos              1
# Ryan Kelly                1
# Victor Oladipo            1
# Reggie Evans              1
# Garret Siler              1
# Luis Scola                1
# Daniel Orton              1
# Joakim Noah               1
# James Johnson             1
# Hollis Thompson           1
# James Harden              1
# Paul Pierce               1
# Darnell Jackson           1
# Jonny Flynn               1
# Jannero Pargo             1
# Jrue Holiday              1
# Marcin Gortat             1
# Omer Asik                 1
# Bradley Beal              1
# Kobe Bryant               1
# Rashard Lewis             1
# Shawne Williams           1
# Perry Jones               1
# Randy Foye                1
# Dexter Pittman            1
# Gerald Henderson          1
# Grant Hill                1
# Rudy Gobert               1
#                          ..
# Tyler Hansbrough          1
# Donte Greene              1
# ...

# %%
#group by using players name
grouped_tattoo_df = tattoo_df.groupby(['Player Name'])
grouped_tattoo_df.head()
# Out:
#             Player Name Tattoos yes/no
# 0            A.J. Price             no
# 1            Aaron Gray             no
# 2            Al Horford             no
# 3          Al Jefferson             no
# 4           Al Thornton             no
# 5         Alan Anderson             no
# 6            Alec Burks             no
# 7          Alexey Shved             no
# 8      Anderson Varejao             no
# 9       Andrea Bargnani             no
# 10         Andrew Bynum             no
# 11     Andrew Nicholson             no
# 12      Andris Biedrins             no
# 13        Anthony Davis             no
# 14       Anthony Parker             no
# 15     Anthony Tolliver             no
# 16      Antonio McDyess             no
# 17        Arron Afflalo             no
# 18        Avery Bradley             no
# 19           Beno Udrih             no
# 20      Bismack Biyombo             no
# 21        Blake Griffin             no
# 22           Boris Diaw             no
# ...
